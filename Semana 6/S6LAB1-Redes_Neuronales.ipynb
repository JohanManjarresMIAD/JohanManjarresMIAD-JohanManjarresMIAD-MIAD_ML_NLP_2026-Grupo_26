# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Redes Neuronales
#
# En este notebook aprenderá a construir y a entrenar redes neuronales de una capa y multicapas, usando la librería [Keras](https://keras.io/).
#
# Este notebook tiene una licencia de [Creative Commons Attribution-ShareAlike 3.0 Unported License](http://creativecommons.org/licenses/by-sa/3.0/deed.en_US). Un agradecimiento especial para [Valerio Maggio](https://mpba.fbk.eu).

# %% [markdown]
# ## Instrucciones Generales
#
# Keras es una librería de redes neuronales altamente modular, escrita en Python y capaz de ejecutarse sobre TensorFlow o Theano. Fue desarrollada con el objetivo de permitir una experimentación rápida con modelos de redes neuronales.
#
# Este notebook esta compuesto por dos secciones. En la primera sección, usted beberá construir y entrenar una red neuronal de una capa para predecir el precio de una casa con el set de datos Boston Housing Data. En la segunda parte, se usará el mismo dataset pero usted beberá construir y entrenar una red neuronal multicapa para identificar sus ventajas. Para conocer más detalles de la base, puede ingresar al siguiente [vínculo](https://archive.ics.uci.edu/ml/machine-learning-databases/housing/).
#
# Para realizar la actividad, solo siga las indicaciones asociadas a cada celda del notebook.

# %% [markdown]
# ## Importar base de datos y librerías

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %%
from sklearn.datasets import fetch_california_housing
# Carga de datos de la librería sklearn
california_housing = fetch_california_housing()
dataset = pd.DataFrame(california_housing.data, columns=california_housing.feature_names)
dataset['PRICE'] = california_housing.target

dataset.head()
# Out:
#    MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  PRICE
# 0    -122.23  4.526
# 1    -122.22  3.585
# 2    -122.24  3.521
# 3    -122.25  3.413
# 4    -122.25  3.422

# %% [markdown]
# ## Definición de variables predictoras  y de interés

# %%
# Definición de variables predictoras (X)
X = dataset.drop('PRICE', axis=1)

# Definición de variable de interés (y)
Y = pd.DataFrame(california_housing.target, columns=['labels'])

# %%
Y
# Out:
#        labels
# 0       4.526
# 1       3.585
# 2       3.521
# 3       3.413
# 4       3.422
# ...       ...
# 20635   0.781
# 20636   0.771
# 20637   0.923
# 20638   0.847
# 20639   0.894
#
# [20640 rows x 1 columns]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
X_train, X_test , Y_train, Y_test = train_test_split(X,Y, test_size=0.3 ,random_state=22)

# %%
# Normalización de variables predictoras (X) con la función StandardScaler
from sklearn.preprocessing import StandardScaler

# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
X_train = pd.DataFrame(data=scaler.transform(X_train), columns=X_train.columns, index=X_train.index)
X_test = pd.DataFrame(data=scaler.transform(X_test), columns=X_test.columns, index=X_test.index)

X_train = np.array(X_train)
Y_train = np.array(Y_train)

X_test = np.array(X_test)
Y_test = np.array(Y_test)

# %%
# Definición de dimensiones de salida, varaibles de interés
output_var = Y_train.shape[1]
print(output_var, ' output variables')
# Out:
# 1  output variables

# %%
# Definición de dimensiones de entrada, varaibles predictoras
dims = X_train.shape[1]
print(dims, 'input variables')
# Out:
# 8 input variables

# %% [markdown]
# # Red neuronal de una sola capa

# %%
pip install livelossplot
# Out:
# Collecting livelossplot
#   Downloading livelossplot-0.6.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: bokeh in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from livelossplot) (3.8.2)
# Requirement already satisfied: matplotlib in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from livelossplot) (3.10.3)
# Requirement already satisfied: Jinja2>=2.9 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (3.1.6)
# Requirement already satisfied: contourpy>=1.2 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (1.3.2)
# Requirement already satisfied: narwhals>=1.13 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (2.16.0)
# Requirement already satisfied: numpy>=1.16 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (2.2.6)
# Requirement already satisfied: packaging>=16.8 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (25.0)
# Requirement already satisfied: pandas>=1.2 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (2.3.0)
# Requirement already satisfied: pillow>=7.1.0 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (11.2.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (6.0.3)
# Requirement already satisfied: tornado>=6.2 in c:\users\johanmanjarres\appdata\roaming\python\python313\site-packages (from bokeh->livelossplot) (6.5.4)
# Requirement already satisfied: xyzservices>=2021.09.1 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from bokeh->livelossplot) (2025.11.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from Jinja2>=2.9->bokeh->livelossplot) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->bokeh->livelossplot) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->bokeh->livelossplot) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->bokeh->livelossplot) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.2->bokeh->livelossplot) (1.17.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->livelossplot) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->livelossplot) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->livelossplot) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\johanmanjarres\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->livelossplot) (3.2.3)
# Downloading livelossplot-0.6.0-py3-none-any.whl (23 kB)
# Installing collected packages: livelossplot
# Successfully installed livelossplot-0.6.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Importación librerías
from keras.models import Sequential
from keras.layers import Dense, Activation
from livelossplot import PlotLossesKeras
from keras import backend as K
import keras.optimizers as opts

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# WARNING:tensorflow:From c:\Users\JohanManjarres\AppData\Local\Programs\Python\Python313\Lib\site-packages\keras\src\backend\common\global_state.py:82: The name tf.reset_default_graph is deprecated. Please use tf.compat.v1.reset_default_graph instead.
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')
# Out:
# WARNING:tensorflow:TensorFlow GPU support is not available on native Windows for TensorFlow >= 2.11. Even if CUDA/cuDNN are installed, GPU will not be used. Please use WSL2 or the TensorFlow-DirectML plugin.

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train, 
          verbose=1, 
          epochs=50, 
          validation_data=(X_test, Y_test),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.936, max:      inf, cur:      inf)
# 	validation       	 (min:    0.937, max:      inf, cur:      inf)
# 452/452 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - loss: inf - val_loss: inf

# %% [markdown]
# ## Red neuronal de una sola capa con early stopping

# %%
# Importación librerías
from sklearn.model_selection import train_test_split
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(output_var, input_shape=(dims,)))
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             9 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 9 (36.00 B)
#  Trainable params: 9 (36.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de la función EarlyStopping para considerar durante el entrenamiento
early_stop = EarlyStopping(monitor='val_loss', patience=2, verbose=1)

# %%
# Definición de la función ModelCheckpoint para guardar el modelo con mejor desempeño
fBestModel = 'best_model.h5'
best_model = ModelCheckpoint(fBestModel, verbose=0, save_best_only=True)

# %%
# Entrenamiento de la red neuronal con 50 épocas y early stopping
model.fit(X_train, Y_train, 
          verbose=True, 
          epochs=50, 
          batch_size=128,
          validation_data=(X_test,Y_test),
          callbacks=[best_model, early_stop])
# Out:
# Epoch 1/50
#  89/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.3649
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 2.6631 - val_loss: 0.6736
# Epoch 2/50
#  91/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.7565
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.7140 - val_loss: 0.5690
# Epoch 3/50
#  92/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6365
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.6049 - val_loss: 0.5369
# Epoch 4/50
#  98/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6556
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5980 - val_loss: 0.5194
# Epoch 5/50
# 101/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5902
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5697 - val_loss: 0.5069
# Epoch 6/50
# 110/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5738
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5658 - val_loss: 0.5052
# Epoch 7/50
# 107/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5604
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5613 - val_loss: 0.4994
# Epoch 8/50
# 105/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5644
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5571 - val_loss: 0.4948
# Epoch 9/50
# 106/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5458
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5488 - val_loss: 0.4943
# Epoch 10/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5481 - val_loss: 0.4977
# Epoch 11/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5431
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5491 - val_loss: 0.4922
# Epoch 12/50
# 108/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5496
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.5506 - val_loss: 0.4921
# Epoch 13/50
# 109/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5633
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.5500 - val_loss: 0.4902
# Epoch 14/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5472 - val_loss: 0.4910
# Epoch 15/50
# 100/113 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5568
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.5505 - val_loss: 0.4900
# Epoch 16/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5485 - val_loss: 0.4903
# Epoch 17/50
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5431 - val_loss: 0.4992
# Epoch 17: early stopping

# %% [markdown]
# # Red Neuronal Multicapa

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()

# Definición de la capa densa con un tamaño de salida igual a output_var y un input_shape de dims
model.add(Dense(256, input_shape=(dims,),activation='relu'))
model.add(Dense(256,activation='relu'))
model.add(Dense(output_var))
model.add(Activation('relu'))

# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,353 (267.00 KB)
#  Trainable params: 68,353 (267.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
# Separación de datos de entrenamiento para considerar un set de validación durante entrenamiento
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.15, random_state=42)

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(X_train, Y_train,
          validation_data = (X_val, Y_val),
          epochs=50, 
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.283, max:    0.763, cur:    0.283)
# 	validation       	 (min:    0.262, max:    0.457, cur:    0.267)
# 384/384 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.2833 - val_loss: 0.2666
